# %%
import yfinance as yf
import pandas as pd
import numpy as np 
from statsmodels.tsa.stattools import coint
from itertools import combinations

bist30 = [
    'AKBNK.IS', 'ARCLK.IS', 'ASELS.IS', 'BIMAS.IS', 'EKGYO.IS', 
    'EREGL.IS', 'FROTO.IS', 'GARAN.IS', 'HEKTS.IS', 'ISCTR.IS', 
    'KCHOL.IS', 'KOZAL.IS', 'KRDMD.IS', 'PETKM.IS', 'PGSUS.IS', 
    'SAHOL.IS', 'SASA.IS', 'SISE.IS', 'TAVHL.IS', 'TCELL.IS', 
    'THYAO.IS', 'TOASO.IS', 'TUPRS.IS', 'VAKBN.IS', 'YKBNK.IS'
]


data = yf.download(bist30, start="2025-01-01", end="2026-01-01")['Close'].dropna()

data_log = np.log(data) 

results = []
pairs = list(combinations(bist30, 2))


for t1, t2 in pairs:
    try:
       
        score, p_value, _ = coint(data_log[t1], data_log[t2])
        
        if p_value < 0.05: 
            results.append((t1, t2, p_value))
    except Exception as e:
        continue


results_df = pd.DataFrame(results, columns=['Hisse 1', 'Hisse 2', 'P-Value'])
results_df = results_df.sort_values(by='P-Value')



print(f"{'HİSSE 1':<12} | {'HİSSE 2':<12} | {'LOG P-VALUE'}")


for index, row in results_df.iterrows():
    print(f"{row['Hisse 1']:<12} | {row['Hisse 2']:<12} | {row['P-Value']:.6f}")
# Out:
# /var/folders/49/q5q_jjls7tq8knq4wvstm17m0000gn/T/ipykernel_15785/3751212861.py:16: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(bist30, start="2025-01-01", end="2026-01-01")['Close'].dropna()
# [*********************100%***********************]  25 of 25 completed
# HİSSE 1      | HİSSE 2      | LOG P-VALUE
# PETKM.IS     | TUPRS.IS     | 0.007720
# PETKM.IS     | TOASO.IS     | 0.008159
# SISE.IS      | VAKBN.IS     | 0.011990
# PETKM.IS     | THYAO.IS     | 0.014995
# BIMAS.IS     | PGSUS.IS     | 0.017212
# BIMAS.IS     | YKBNK.IS     | 0.022870
# AKBNK.IS     | VAKBN.IS     | 0.024737
# AKBNK.IS     | KCHOL.IS     | 0.027060
# BIMAS.IS     | TOASO.IS     | 0.027852
# PETKM.IS     | SASA.IS      | 0.028488
# PETKM.IS     | PGSUS.IS     | 0.029772
# PETKM.IS     | YKBNK.IS     | 0.032662
# PETKM.IS     | TAVHL.IS     | 0.035101
# PETKM.IS     | VAKBN.IS     | 0.037212
# PETKM.IS     | SAHOL.IS     | 0.038426
# TCELL.IS     | YKBNK.IS     | 0.042107
# BIMAS.IS     | TUPRS.IS     | 0.043316
# PETKM.IS     | TCELL.IS     | 0.044504
# HEKTS.IS     | PETKM.IS     | 0.045438
# BIMAS.IS     | EKGYO.IS     | 0.047325
# VAKBN.IS     | YKBNK.IS     | 0.047394
# SISE.IS      | YKBNK.IS     | 0.047846
